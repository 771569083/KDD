# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
ex = pd.read_csv('train.csv')
ex = ex.dropna()
x_train = ex.iloc[:,:-1].values.reshape(-1,1)
y_train = ex.iloc[:,1: ].values.reshape(-1,1)
# print(x_train)
# print(y_train)
plt.figure(figsize=(16,9))
# a = plt.scatter(x_train,y_train,color='blue')
# plt.show()
lrModel = LinearRegression()
lrModel.fit(x_train,y_train)
print(lrModel.coef_,lrModel.intercept_)
Y_pred = lrModel.predict(x_train)
# print(y_train)
plt.plot(x_train,Y_pred,'r',x_train,y_train,'bo')
# Out:
# [[1.00065638]] [-0.10726546]
# ...

# %%
from sklearn import metrics

ex_1 = pd.read_csv('test.csv')
ex_1 = ex_1.dropna()
x_test = ex_1.iloc[:,:-1].values.reshape(-1,1)
y_test = ex_1.iloc[:,1:].values.reshape(-1,1)
y_pred = lrModel.predict(x_test)
print("MSE ",metrics.mean_squared_error(y_test, y_pred))
print("RMSE ",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MSE  9.432922192039305
# RMSE  3.071306268029827

# %%
from sklearn.model_selection import train_test_split
Multi_ex = pd.read_csv('CCPP.csv')
Multi_ex = Multi_ex.dropna()
X_test = Multi_ex.iloc[:,:-1].values.reshape(-1,4)
Y_test = Multi_ex.iloc[:,-1:].values.reshape(-1,1)
X_train, X_test, Y_train, Y_test = train_test_split(X_test,Y_test, test_size=0.2, shuffle=False)
lrModel.fit(X_train,Y_train)
Y_pred = lrModel.predict(X_test)
print("MSE ",metrics.mean_squared_error(Y_test, Y_pred))
print("RMSE ",np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
Y_pred = lrModel.predict(X_train)
plt.figure(figsize=(16,9))
print(lrModel.coef_)
a = plt.plot(X_train[:,0:1],Y_pred,':r',X_train[:,1:2],Y_pred,':b',X_train[:,2:3],Y_pred,'--g',X_train[:,3:4],Y_pred,'--y')
# Out:
# MSE  21.73110349264593
# RMSE  4.661663168081316
# [[-1.99227168 -0.22713758  0.06183797 -0.16061702]]
