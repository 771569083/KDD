# %%
import pandas as pd
import numpy as np
import seaborn as sns
import chardet

q1 = pd.read_csv("landslide_catalog.csv")
q1.sample(10)
# Out:
#         id      date      time continent_code  \
# 172    941  12/20/08       NaN            NaN
# 1669  7514   5/23/15       NaN            NaN
# 634   3357   4/12/11       NaN            NaN
# 36     238    9/6/07       NaN            NaN
# 1473  6994   4/29/15       NaN            NaN
# 346   1886   5/22/10  18:00:00            NaN
# 149    800   9/20/08       NaN            NaN
# 1337  6508   8/14/14   evening            NaN
# 474   2543   10/4/10       NaN            NaN
# 866   4252    3/9/12       NaN            NaN
#
#                           country_name country_code state/province  \
# 172                Trinidad and Tobago           TT     Penal/Debe
# 1669                            Mexico           MX        Chiapas
# 634   Saint Vincent and the Grenadines           VC      Charlotte
# 36                       United States           US       Colorado
# 1473                     United States           US       Colorado
# ...

# %%
print(q1["date"])
q1["date_prased"]=pd.to_datetime(q1["date"])
print(q1["date_prased"])
# Out:
# 0        3/2/07
# 1       3/22/07
# 2        4/6/07
# 3       4/14/07
# 4       4/15/07
#          ...
# 1688    12/7/15
# 1689    2/22/16
# 1690    2/23/16
# 1691    2/26/16
# 1692     3/2/16
# Name: date, Length: 1693, dtype: object
# 0      2007-03-02
# 1      2007-03-22
# 2      2007-04-06
# 3      2007-04-14
# 4      2007-04-15
#           ...
# 1688   2015-12-07
# 1689   2016-02-22
# 1690   2016-02-23
# 1691   2016-02-26
# 1692   2016-03-02
# Name: date_prased, Length: 1693, dtype: datetime64[ns]

# %%
day = q1["date_prased"].dt.day
day.head()
sns.displot(day, kde=False, bins=31)

# %%
with open("volcano_database.csv",'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
print(result)
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.7297389971907721, 'language': ''}

# %%
q2 = pd.read_csv("volcano_database.csv",encoding='ISO-8859-1')
q2.sample()
# Out:
#      Number                Name Country                  Region  \
# 988  320170  Bridge River Cones  Canada  Canada and Western USA
#
#                Type  Activity Evidence Last Known Eruption  Latitude  \
# 988  Volcanic field  Evidence Credible             Unknown      50.8
#
#      Longitude  Elevation (Meters)     Dominant Rock Type  \
# 988     -123.4                2500  Basalt / Picro-Basalt
#
#                                  Tectonic Setting
# 988  Subduction Zone / Continental Crust (>25 km)

# %%
q3 = pd.read_csv('Reviews.csv')
q3_ndp = q3.drop_duplicates()
print(q3_ndp.size)
print(q3.size)
print(len(q3_ndp))
print(len(q3))
# Out:
# 5684540
# 5684540
# 568454
# 568454
